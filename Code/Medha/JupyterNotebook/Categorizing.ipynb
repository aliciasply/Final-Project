# %%
import pandas as pd 
df = pd.read_csv("final_categorized_data.csv") 
df.head()
# Out:
#    Unnamed: 0 Title                                            Article  \
# 0           0   CNN  Po Murray writes that the two mass killings in...
# 1           1   CNN  Mississippi is one of three states that have e...
# 2           2   CNN  In 2018, the city of Boulder, Colorado, passed...
# 3           3   CNN  "The life of a single parent is challenging to...
# 4           4   CNN  British people attempting to go on vacation wh...
#
#                                             Headline  \
# 0  Opinion: What has to happen after the Colorado...
# 1  More states aim to offer Covid-19 vaccines to ...
# 2  Boulder banned assault weapons in 2018. A judg...
# 3  Opinion: My Covid life as a single mom: Like j...
# 4  New UK law means $7,000 fines for vacations ab...
#
#                                            Title_URL  \
# 0  https://www.facebook.com/cnn/?__cft__[0]=AZVAV...
# 1  https://www.facebook.com/cnn/?__cft__[0]=AZU2o...
# ...

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['Unnamed: 0', 'Title', 'Article', 'Headline', 'Title_URL', 'Image',
#        'Facebook_likes', 'Facebook_comments', 'Facebook_shares',
#        'Comment_replies', 'results'],
#       dtype='object')

# %%
df_real=df.loc[df["results"]=="'REAL'"]
df_real
# Out:
#       Unnamed: 0              Title  \
# 0              0                CNN
# 7              7                CNN
# 8              8                CNN
# 9              9                CNN
# 10            10                CNN
# ...          ...                ...
# 1970         927  BuzzFeed Politics
# 1974         931  BuzzFeed Politics
# 1977         934  BuzzFeed Politics
# 1979         936  BuzzFeed Politics
# 1980         937  BuzzFeed Politics
#
#                                                 Article  \
# 0     Po Murray writes that the two mass killings in...
# 7     Police identified the 10 victims of the Boulde...
# 8     Republicans at the state level have moved swif...
# 9     President Biden used the latest mass shooting ...
# 10    Former President Barack Obama called for stric...
# ...                                                 ...
# 1970  The New York governor questioned the motives o...
# 1974  Supporters say they’re “defending women’s spor...
# ...

# %%
df_real.to_csv('realdata.csv', encoding='utf-8')

# %%
df_fake = df.loc[df["results"]=="'FAKE'"]
df_fake
# Out:
#       Unnamed: 0              Title  \
# 1              1                CNN
# 2              2                CNN
# 3              3                CNN
# 4              4                CNN
# 5              5                CNN
# ...          ...                ...
# 1973         930  BuzzFeed Politics
# 1975         932  BuzzFeed Politics
# 1976         933  BuzzFeed Politics
# 1978         935  BuzzFeed Politics
# 1981         938  BuzzFeed Politics
#
#                                                 Article  \
# 1     Mississippi is one of three states that have e...
# 2     In 2018, the city of Boulder, Colorado, passed...
# 3     "The life of a single parent is challenging to...
# 4     British people attempting to go on vacation wh...
# 5     Former first lady Michelle Obama and a host of...
# ...                                                 ...
# 1973  Politicians in Congress are talking about retu...
# 1975  US officials are considering a number of optio...
# ...

# %%
df_fake.to_csv('fakedata.csv', encoding='utf-8')
